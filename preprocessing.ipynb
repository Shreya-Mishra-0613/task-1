# %%
import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('data/healthcare_noshows_appt.csv')
df.sample(10)
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 31880   9.493999e+12        5671171      F   2016-05-06     2016-05-17   22
# 71570   3.538542e+13        5652728      M   2016-05-03     2016-05-09   14
# 90497   3.475467e+13        5783925      F   2016-06-07     2016-06-07    9
# 94976   5.647598e+13        5767926      M   2016-06-03     2016-06-03   13
# 52825   8.326380e+13        5686832      F   2016-05-11     2016-05-17   16
# 5932    4.388696e+12        5693781      F   2016-05-13     2016-05-17   17
# 24460   6.315699e+13        5623311      F   2016-04-26     2016-05-16   44
# 15871   6.947419e+12        5607822      F   2016-04-20     2016-05-02    5
# 106630  7.983679e+13        5772341      F   2016-06-03     2016-06-07   44
# 60307   2.764517e+13        5548984      F   2016-04-06     2016-05-09   84
#
#             Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 31880        PRAIA DO SUÁ        False         False     False       False
# 71570           SÃO PEDRO         True         False     False       False
# 90497            REDENÇÃO        False         False     False       False
# 94976          TABUAZEIRO        False         False     False       False
# 52825          BELA VISTA        False         False     False       False
# 5932           ANDORINHAS         True         False     False       False
# 24460   JESUS DE NAZARETH        False         False     False       False
# 15871          TABUAZEIRO        False         False     False       False
# 106630         GOIABEIRAS         True          True     False       False
# 60307        SOLON BORGES        False         False     False       False
#
#         Handcap  SMS_received  Showed_up  Date.diff
# 31880     False         False      False         11
# 71570     False         False      False          6
# 90497     False         False       True          0
# 94976     False         False       True          0
# 52825     False         False       True          6
# 5932      False         False       True          4
# 24460     False         False       True         20
# 15871     False          True       True         12
# 106630    False          True       True          4
# 60307     False         False       True         33

# %%
# Rows and columns
df.shape
# Out:
# (106987, 15)

# %%
# Data types and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106987 entries, 0 to 106986
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       106987 non-null  float64
#  1   AppointmentID   106987 non-null  int64
#  2   Gender          106987 non-null  object
#  3   ScheduledDay    106987 non-null  object
#  4   AppointmentDay  106987 non-null  object
#  5   Age             106987 non-null  int64
#  6   Neighbourhood   106987 non-null  object
#  7   Scholarship     106987 non-null  bool
#  8   Hipertension    106987 non-null  bool
#  9   Diabetes        106987 non-null  bool
#  10  Alcoholism      106987 non-null  bool
#  11  Handcap         106987 non-null  bool
#  12  SMS_received    106987 non-null  bool
#  13  Showed_up       106987 non-null  bool
#  14  Date.diff       106987 non-null  int64
# dtypes: bool(7), float64(1), int64(3), object(4)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Insights
# - Convert PatientId to int64 data type (memory efficiency)
# - No null values in any column

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# Showed_up         0
# Date.diff         0
# dtype: int64

# %% [markdown]
# #### We can see that our data has no missing values

# %%
# Statistical summary
df.describe()
# Out:
#           PatientId  AppointmentID            Age      Date.diff
# count  1.069870e+05   1.069870e+05  106987.000000  106987.000000
# mean   1.472814e+14   5.675434e+06      38.316085      10.166721
# std    2.558267e+14   7.133274e+04      22.466214      15.263508
# min    3.921784e+04   5.030230e+06       1.000000      -6.000000
# 25%    4.173523e+12   5.640490e+06      19.000000       0.000000
# 50%    3.172463e+13   5.680744e+06      38.000000       4.000000
# 75%    9.433600e+13   5.725634e+06      56.000000      14.000000
# max    9.999816e+14   5.790484e+06     115.000000     179.000000

# %% [markdown]
# ### Insights
# - Difference between scheduledDay and AppointmentDay cannot be negative

# %%
# Column names
df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'Showed_up',
#        'Date.diff'],
#       dtype='object')

# %%
#Renaming column headers to be clean and uniform (Capitalized)
df.rename(columns={
    'Date.diff': 'DateDifference',
    'SMS_received': 'SMSReceived',
    'Showed_up' : 'ShowedUp'
}, inplace=True)

df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMSReceived', 'ShowedUp',
#        'DateDifference'],
#       dtype='object')

# %% [markdown]
# ### Checking for Duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### No Duplicates

# %%
#Unique values in each Column
df.nunique()
# Out:
# PatientId          60270
# AppointmentID     106987
# Gender                 2
# ScheduledDay         110
# AppointmentDay        27
# Age                  102
# Neighbourhood         81
# Scholarship            2
# Hipertension           2
# Diabetes               2
# Alcoholism             2
# Handcap                2
# SMSReceived            2
# ShowedUp               2
# DateDifference       131
# dtype: int64

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# ### Convert Date Columns to datetime

# %%
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay'])
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay'])

# %%
df.sample(10)
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 104584  1.564985e+13        5788520      M   2016-06-08     2016-06-08    2
# 104965  1.578939e+14        5641291      M   2016-04-29     2016-06-08   21
# 17909   6.625232e+12        5747574      M   2016-05-30     2016-05-30   58
# 75630   4.315728e+14        5712034      F   2016-05-18     2016-05-25   49
# 33381   3.781589e+10        5675820      M   2016-05-09     2016-05-09   27
# 18208   8.632243e+11        5711012      M   2016-05-18     2016-05-18   18
# 20901   3.866534e+14        5649348      F   2016-05-02     2016-05-11   41
# 41831   1.572296e+14        5753828      F   2016-05-31     2016-05-31   14
# 8088    6.392776e+11        5674046      F   2016-05-09     2016-05-09   60
# 99839   3.881649e+12        5767727      M   2016-06-03     2016-06-08   10
#
#            Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 104584     SANTO ANTÔNIO        False         False     False       False
# 104965             ROMÃO        False         False     False       False
# 17909        MARIA ORTIZ        False         False     False       False
# 75630       SANTA MARTHA        False         False      True       False
# 33381         TABUAZEIRO        False         False     False       False
# 18208     FORTE SÃO JOÃO        False         False     False       False
# 20901           GURIGICA        False         False     False       False
# 41831   ILHA DO PRÍNCIPE         True         False     False       False
# 8088           DO QUADRO        False          True      True       False
# 99839             BONFIM        False         False     False       False
#
#         Handcap  SMSReceived  ShowedUp  DateDifference
# 104584    False        False      True               0
# 104965    False        False      True              40
# 17909     False        False      True               0
# 75630     False         True      True               7
# 33381     False        False      True               0
# 18208     False        False      True               0
# 20901     False         True      True               9
# 41831     False        False      True               0
# 8088      False        False      True               0
# 99839     False         True      True               5

# %% [markdown]
# ### Removing rows with negative DateDifference

# %%
negative_diff_df = df[df['DateDifference'] < 0]

# %%
negative_diff_df.shape
# Out:
# (5, 15)

# %%
negative_diff_df.sample(5)
# Out:
#           PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 26222  7.839273e+12        5679978      M   2016-05-10     2016-05-09   38
# 53324  7.896294e+12        5715660      F   2016-05-18     2016-05-17   19
# 62055  2.425226e+13        5664962      F   2016-05-05     2016-05-04   22
# 70039  3.787482e+12        5655637      M   2016-05-04     2016-05-03    7
# 69225  9.982316e+14        5686628      F   2016-05-11     2016-05-05   81
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 26222    RESISTÊNCIA        False         False     False       False
# 53324  SANTO ANTÔNIO        False         False     False       False
# 62055     CONSOLAÇÃO        False         False     False       False
# 70039     TABUAZEIRO        False         False     False       False
# 69225  SANTO ANTÔNIO        False         False     False       False
#
#        Handcap  SMSReceived  ShowedUp  DateDifference
# 26222     True        False     False              -1
# 53324     True        False     False              -1
# 62055    False        False     False              -1
# 70039    False        False     False              -1
# 69225    False        False     False              -6

# %%
df = df[df['DateDifference'] >= 0]

# %%
df.describe()
# Out:
#           PatientId  AppointmentID                   ScheduledDay  \
# count  1.069820e+05   1.069820e+05                         106982
# mean   1.472785e+14   5.675434e+06  2016-05-08 21:18:50.455590400
# min    3.921784e+04   5.030230e+06            2015-11-10 00:00:00
# 25%    4.173345e+12   5.640488e+06            2016-04-29 00:00:00
# 50%    3.172598e+13   5.680744e+06            2016-05-10 00:00:00
# 75%    9.433627e+13   5.725639e+06            2016-05-20 00:00:00
# max    9.999816e+14   5.790484e+06            2016-06-08 00:00:00
# std    2.558181e+14   7.133426e+04                            NaN
#
#                       AppointmentDay            Age  DateDifference
# count                         106982  106982.000000   106982.000000
# mean   2016-05-19 01:19:44.296423424      38.316315       10.167290
# min              2016-04-29 00:00:00       1.000000        0.000000
# 25%              2016-05-09 00:00:00      19.000000        0.000000
# 50%              2016-05-18 00:00:00      38.000000        4.000000
# 75%              2016-05-31 00:00:00      56.000000       14.000000
# max              2016-06-08 00:00:00     115.000000      179.000000
# std                              NaN      22.466023       15.263631

# %% [markdown]
# #### Invalid entries are removed

# %% [markdown]
# ### Checking and fixing data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106982 entries, 0 to 106986
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       106982 non-null  float64
#  1   AppointmentID   106982 non-null  int64
#  2   Gender          106982 non-null  object
#  3   ScheduledDay    106982 non-null  datetime64[ns]
#  4   AppointmentDay  106982 non-null  datetime64[ns]
#  5   Age             106982 non-null  int64
#  6   Neighbourhood   106982 non-null  object
#  7   Scholarship     106982 non-null  bool
#  8   Hipertension    106982 non-null  bool
#  9   Diabetes        106982 non-null  bool
#  10  Alcoholism      106982 non-null  bool
#  11  Handcap         106982 non-null  bool
#  12  SMSReceived     106982 non-null  bool
#  13  ShowedUp        106982 non-null  bool
#  14  DateDifference  106982 non-null  int64
# dtypes: bool(7), datetime64[ns](2), float64(1), int64(3), object(2)
# memory usage: 8.1+ MB

# %%
df['PatientId'] = df['PatientId'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106982 entries, 0 to 106986
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       106982 non-null  int64
#  1   AppointmentID   106982 non-null  int64
#  2   Gender          106982 non-null  object
#  3   ScheduledDay    106982 non-null  datetime64[ns]
#  4   AppointmentDay  106982 non-null  datetime64[ns]
#  5   Age             106982 non-null  int64
#  6   Neighbourhood   106982 non-null  object
#  7   Scholarship     106982 non-null  bool
#  8   Hipertension    106982 non-null  bool
#  9   Diabetes        106982 non-null  bool
#  10  Alcoholism      106982 non-null  bool
#  11  Handcap         106982 non-null  bool
#  12  SMSReceived     106982 non-null  bool
#  13  ShowedUp        106982 non-null  bool
#  14  DateDifference  106982 non-null  int64
# dtypes: bool(7), datetime64[ns](2), int64(4), object(2)
# memory usage: 8.1+ MB

# %% [markdown]
# ## Saving Cleaned Data

# %%
df.to_csv('data/cleaned_healthcare_noshows.csv', index=False)
